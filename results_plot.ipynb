# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('results.csv')

# %%
fig = plt.figure(figsize=(15,8))
ax = sns.barplot(data=df, x='method', y='proc_time', estimator=np.sum)
ax.set(xlabel='Method', ylabel='Processing Time (s)')
# Out:
# [<matplotlib.text.Text at 0x7f52c5a84690>,
#  <matplotlib.text.Text at 0x7f52c5ac3fd0>]
